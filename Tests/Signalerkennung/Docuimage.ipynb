# %%
import numpy as np
import cv2
import matplotlib as mpl
from matplotlib.pyplot import *
import matplotlib.pyplot as plt
import glob

# %%
images = [cv2.imread(file) for file in glob.glob(r"Docuimage/*.jpg")]
for n in range(0, len(images)):
    img = images[n]
    imshow(img[:][:][::])

# %%
    for img in glob.glob(r"Docuimage/*.jpg"):
        try :
            var_img = cv2.imread(img)
            imshow(var_img[:][:][::])
        
        except Exception as e:
            print (e)
